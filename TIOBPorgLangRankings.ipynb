# %%
import tiobeindexpy as tbpy

# %%
from tiobeindexpy import tiobeindexpy as tbpy

# %%
import seaborn as sns

# %%
sns.set(style = "whitegrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
top_20 = tbpy.top_20()

# %%
top_20
# Out:
#     Jan 2020  Jan 2019  Change  Programming Language  Ratings Change.1
# 0          1         1     NaN                  Java  16.896%   -0.01%
# 1          2         2     NaN                     C  15.773%   +2.44%
# 2          3         3     NaN                Python   9.704%   +1.41%
# 3          4         4     NaN                   C++   5.574%   -2.58%
# 4          5         7     NaN                    C#   5.349%   +2.07%
# 5          6         5     NaN     Visual Basic .NET   5.287%   -1.17%
# 6          7         6     NaN            JavaScript   2.451%   -0.85%
# 7          8         8     NaN                   PHP   2.405%   -0.28%
# 8          9        15     NaN                 Swift   1.795%   +0.61%
# 9         10         9     NaN                   SQL   1.504%   -0.77%
# 10        11        18     NaN                  Ruby   1.063%   -0.03%
# 11        12        17     NaN  Delphi/Object Pascal   0.997%   -0.10%
# 12        13        10     NaN           Objective-C   0.929%   -0.85%
# 13        14        16     NaN                    Go   0.900%   -0.22%
# 14        15        14     NaN     Assembly language   0.877%   -0.32%
# 15        16        20     NaN          Visual Basic   0.831%   -0.20%
# 16        17        25     NaN                     D   0.825%   +0.25%
# 17        18        12     NaN                     R   0.808%   -0.52%
# 18        19        13     NaN                  Perl   0.746%   -0.48%
# 19        20        11     NaN                MATLAB   0.737%   -0.76%

# %%
top_20['Ratings'] = top_20.loc[:,'Ratings'].apply(lambda x: float(x.strip("%")))
top_20['Change.1'] = top_20.loc[:,'Change.1'].apply(lambda x: float(x.strip("%")))

# %%
sns.barplot('Ratings', 'Programming Language', data = top_20).set_title('Mar 2019 - Programming Popularity')
# Out:
# Text(0.5,1,'Mar 2019 - Programming Popularity')

# %%
sns.barplot('Programming Language', 'Change.1', 
            data = top_20.sort_values("Change.1",ascending = False)[0:5]).set_title('Mar 2018 vs 2019 - Language Popularity - Biggest Gainers from Top 20')
# Out:
# Text(0.5,1,'Mar 2018 vs 2019 - Language Popularity - Biggest Gainers from Top 20')

# %%
sns.barplot('Change.1', 'Programming Language', 
            data = top_20.sort_values("Change.1",ascending = True)[0:5]).set_title('Mar 2018 vs 2019 - Language Popularity - Biggest Losers from Top 20')
# Out:
# Text(0.5,1,'Mar 2018 vs 2019 - Language Popularity - Biggest Losers from Top 20')

# %%
hof = tbpy.hall_of_fame()

# %%
hof.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow1_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow1_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow2_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow2_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow3_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow3_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow4_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow4_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow5_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow5_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow6_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow6_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow7_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow7_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow8_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow8_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow9_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow9_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow10_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow10_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow11_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow11_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow12_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow12_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow13_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow13_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow14_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow14_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow15_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow15_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }</style>
# <table id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Year</th>
#         <th class="col_heading level0 col1" >Winner</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow0_col0" class="data row0 col0" >2018</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow0_col1" class="data row0 col1" >Python</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow1_col0" class="data row1 col0" >2017</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow1_col1" class="data row1 col1" >C</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow2_col0" class="data row2 col0" >2016</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow2_col1" class="data row2 col1" >Go</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow3_col0" class="data row3 col0" >2015</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow3_col1" class="data row3 col1" >Java</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow4_col0" class="data row4 col0" >2014</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow4_col1" class="data row4 col1" >JavaScript</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow5_col0" class="data row5 col0" >2013</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow5_col1" class="data row5 col1" >Transact-SQL</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09elevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow6_col0" class="data row6 col0" >2012</td>
#         <td id="T_7bcfac48_3e25_11ea_8045_7cdd90cee09erow6_col1" class="data row6 col1" >Objective-C</td>
#     </tr>    <tr>
#         <th id="T_7bcfac48_3e25_11ea_8
